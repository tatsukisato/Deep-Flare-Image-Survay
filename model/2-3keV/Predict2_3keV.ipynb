# %%
import tensorflow as tf
from keras.models import load_model
import os
from keras.preprocessing.image import img_to_array, load_img
from keras.models import load_model
import numpy as np
from PIL import Image
import pandas as pd
pd.set_option('display.max_rows', 1000)

from keras import backend as K
K.clear_session()
config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))
sess = tf.Session(config=config)
K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
#学習済みモデルの読込
model_file_name='./model_.09-0.07.hdf5'
model=load_model(model_file_name)
model.summary()
# Out:
# WARNING:tensorflow:From /home/tsato/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/tsato/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/tsato/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# ...

# %%
#推測するディレクトリーを指定
print('target name:')
print(os.listdir('../../images/1orbit/2-3keV/test/'))
TARGET_DIR = input('>>> ')
print('predict directory:')
print(os.listdir('../../images/1orbit/2-3keV/test'+'/' + TARGET_DIR+'/'))
IMAGE_DIR = input('>>> ')
images = os.listdir('../../images/1orbit/2-3keV/test/'+TARGET_DIR+'/'+IMAGE_DIR)
#TextName = TARGET_DIR + "_" +IMAGE_DIR + "_" +'1orb.txt'

print("1orbit:" + str(len(images)))
# Out:
# target name:
# ['cdfS', 'RXTE6', 'GTMus', 'RXTE2']
# >>> GTMus
# predict directory:
# ['2013', '2017', '2009', '2018', '2015', '2012', '2016', '2010', '2014', '2011']
# >>> 2018
# 1orbit:4450

# %%
#val以上の評価
df = []
for jpeg_name in images:
    img_path = (jpeg_name)
    img = img_to_array(load_img('/home/tsato/work/machine_learning/CNN/images/1orbit/2-3keV/test/' + TARGET_DIR +'/'+ IMAGE_DIR + '/' + img_path, target_size=(32,32)).convert('L'))
    img_nad = img_to_array(img)/255	    #0-1に変換
    img_nad = img_nad[None, ...]	    #四次元配列に
    label=['background','flare']
    pred = model.predict(img_nad, batch_size=1, verbose=0)
    score = np.max(pred)
    pred_label = label[np.argmax(pred[0])]
    val = 0.99
    if score > val and pred_label == "flare":
        #print (jpeg_name)
        #print('name:',pred_label)
        #print('score:',score)
        #print('\n')
        a=jpeg_name.split("_")
        list=[int(a[0]),jpeg_name,score]     
        df.append(list)
        #df = df.to_csv(jpeg_name,mode='a')
result = pd.DataFrame(df)
result = result.sort_values([0])
result = result.reset_index(drop=True)
result = result.iloc[:,1:3]
#print(result)

# %%
result
# Out:
#                                       1         2
# 0     087_58126.893519-58126.899641.jpg  0.998793
# 1     090_58127.086412-58127.092373.jpg  0.999025
# 2     167_58132.097639-58132.103391.jpg  0.999833
# 3     195_58133.897014-58133.902326.jpg  0.997888
# 4     388_58148.556852-58148.560150.jpg  0.999568
# 5     401_58149.457338-58149.460590.jpg  0.999422
# 6     418_58150.550787-58150.554016.jpg  0.998323
# 7     441_58152.030278-58152.033461.jpg  0.998684
# 8     449_58152.544815-58152.547951.jpg  0.995926
# 9     459_58153.188542-58153.191146.jpg  0.999871
# 10    475_58154.218056-58154.220312.jpg  0.997706
# 11    477_58154.345926-58154.348993.jpg  0.993408
# 12    519_58157.111968-58157.114942.jpg  0.995501
# 13    532_58157.948241-58157.951169.jpg  0.998253
# 14    570_58160.392685-58160.395590.jpg  0.999645
# 15    585_58161.357593-58161.360521.jpg  0.996515
# 16    588_58161.550556-58161.553484.jpg  0.998449
# 17    601_58162.386829-58162.389757.jpg  0.994109
# ...

# %%
#rootで読み込むために保存の場合
for jpeg_name in images:
    img_path = (jpeg_name)
    img = img_to_array(load_img('/home/tsato/work/machine_learning/CNN/images/1orbit/validation/'+TARGET_DIR+'/'+IMAGE_DIR+'/'+ img_path,target_size=(32,32)).convert('L'))
    img_nad = img_to_array(img)/255
    img_nad = img_nad[None, ...]
    label=['0','1']
    pred = model.predict(img_nad, batch_size=1, verbose=0)
    score = np.max(pred)
    pred_label = label[np.argmax(pred[0])]
    root=os.path.splitext(img_path)[0]
    num,time=root.split('_')
    stime,etime=time.split('-')
    with open(TextName, "a") as f:
        print(num,stime,etime,pred[0][0],pred[0][1],pred_label,file=f)

# %%
import ROOT
import sys
import os

DataFileName = TextName
OutFileName = TARGET_DIR + "_" + IMAGE_DIR + "_" + '1orb.root'

tree = ROOT.TTree("EventTree", "EventTree")
tree.ReadFile(DataFileName, "Number:StartTime:EndTime:BackgroundProb:FlareProb:Label")
tree.SaveAs(OutFileName)
# Out:
# Info in <TTree::SaveAs>: ROOT file lockmanhole_2014_1orb.root has been created
